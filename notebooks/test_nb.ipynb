# %%
import sys
# !{sys.executable} -m pip install pandas matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\phuc\documents\python\.venv\lib\site-packages (3.0.2)
# Requirement already satisfied: matplotlib in c:\users\phuc\documents\python\.venv\lib\site-packages (3.10.8)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\phuc\documents\python\.venv\lib\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\phuc\documents\python\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\phuc\documents\python\.venv\lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\phuc\documents\python\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\phuc\documents\python\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\phuc\documents\python\.venv\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\phuc\documents\python\.venv\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\phuc\documents\python\.venv\lib\site-packages (from matplotlib) (26.1)
# Requirement already satisfied: pillow>=8 in c:\users\phuc\documents\python\.venv\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\phuc\documents\python\.venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\phuc\documents\python\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import os

def load_all_data(folder_path):
    all_data = {}
    # Loop through every file in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".csv"):
            # Create the full path
            file_path = os.path.join(folder_path, filename)
            # Use the filename (without .csv) as the key
            key = filename.replace(".csv", "")
            # Load the file
            all_data[key] = pd.read_csv(file_path)
            print(f"Loaded {filename} into all_data['{key}']")
    return all_data

data_dict = load_all_data('../data/')
df_orders = data_dict['orders']
# Out:
# Loaded customers.csv into all_data['customers']
# Loaded geography.csv into all_data['geography']
# Loaded inventory.csv into all_data['inventory']
# Loaded orders.csv into all_data['orders']
# C:\Users\Phuc\AppData\Local\Temp\ipykernel_5024\2201145496.py:14: DtypeWarning: Columns (0: promo_id_2) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_data[key] = pd.read_csv(file_path)
# Loaded order_items.csv into all_data['order_items']
# Loaded payments.csv into all_data['payments']
# Loaded products.csv into all_data['products']
# Loaded promotions.csv into all_data['promotions']
# Loaded returns.csv into all_data['returns']
# Loaded reviews.csv into all_data['reviews']
# Loaded sales.csv into all_data['sales']
# Loaded sample_submission.csv into all_data['sample_submission']
# Loaded shipments.csv into all_data['shipments']
# Loaded web_traffic.csv into all_data['web_traffic']

# %%
type(df_orders)
# Out:
# pandas.DataFrame
